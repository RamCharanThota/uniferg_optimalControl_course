# %%
# solve optimisaton problem with constrains using barrier method 
# and primal and dual interior point 

import autograd.numpy as np
from autograd import grad,jacobian,hessian
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# given function
def fun(x1,x2):
    #x1,x2=x
    return x1**2+x2**2
# given constraints are
# -x1-2*x2 +6>=0 and x1>=0 and x2>=0
# 2x1+x2-6<=0

#add the constrains as the barrier function to the cost

t=10 # log function weight 

def modifiedfun(x):
      x1,x2=x
      return (x1**2+x2**2)+(np.log(6-x1-2*x2)/t)+(np.log(6-2*x1-x2)/t)+(np.log(x1)/t)+(np.log(x1)/t)
    
#gradient of the function
grad_f= jacobian(modifiedfun)

# hessian of the function
hess_f = hessian(modifiedfun)

x0=np.array([0.5,0.5])
print(grad_f(x0))
print(hess_f(x0))


# using the newton method to find the minimum to statisfy the above modified function

X=[np.zeros(2) for i in range(101)]

X[0]=x0


for i in range(5):
    dx= -np.dot(np.linalg.inv(hess_f(x0)),grad_f(x0))
    x0=x0+dx
    X[i+1]=x0

position_trajectory=[array[0] for array in X]
vel_trajectory=[array[1] for array in X]
# Out:
# [1.33333333 0.93333333]
# [[ 1.17530864 -0.01975309]
#  [-0.01975309  1.97530864]]

# %%
# Generate x and y values
x1 = np.linspace(-10, 10, 100)
x2 = np.linspace(-10, 10, 100)
X1, X2 = np.meshgrid(x1, x2)
Z = fun(X1, X2)

# Define the lines
def line1(x1):
    return (6 - x1) / 2

def line2(x1):
    return 6 - 2*x1
# Calculate corresponding y values for each line
# Generate x values
y1 = line1(x1)
y2 = line2(x1)


# Plot the function
plt.figure(figsize=(8, 6))
plt.contourf(X1, X2, Z, levels=20, cmap='viridis')
plt.plot(x1, y1, label='x1 + 2x2 = 6', color='red')
plt.plot(x1, y2, label='2x1 + x2 = 6', color='blue')
plt.plot(position_trajectory,vel_trajectory)
plt.colorbar(label='f(x)')
plt.xlim(-10,10)
plt.ylim(-10,10)

plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Plot of f(x) = x1^2 + x2^2')
plt.grid(True)
plt.show()

# %%
# Out:
# /tmp/ipykernel_16788/2273742171.py:36: UserWarning: The following kwargs were not used by contour: 'label'
#   plt.contourf(X1, X2, inequality_result1, levels=[-10, 0], colors='blue', alpha=0.3, label='x1 + 2x2 <= 6')
# /tmp/ipykernel_16788/2273742171.py:37: UserWarning: The following kwargs were not used by contour: 'label'
#   plt.contourf(X1, X2, inequality_result2, levels=[-10, 0], colors='green', alpha=0.3, label='2x1 + x2 <= 6')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 40
#      37 plt.contourf(X1, X2, inequality_result2, levels=[-10, 0], colors='green', alpha=0.3, label='2x1 + x2 <= 6')
#      39 # Shade the feasible region
# ---> 40 plt.contourf(X1, X2, inequality_result3, levels=[-10, 0], colors='gray', alpha=0.3, label='x1 >= 0')
#      41 plt.contourf(X1, X2, inequality_result4, levels=[-10, 0], colors='gray', alpha=0.3, label='x2 >= 0')
# ...

# %%
# Generate x and y values
x1 = np.linspace(0.1, 10, 100)
x2 = np.linspace(0.1, 10, 100)
X1, X2 = np.meshgrid(x1, x2)
Z = modifiedfun(X1, X2)

# Plot the function
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X1, X2, Z, cmap='viridis')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('f(x)')
ax.set_title('3D Plot of f(x) = x1^2 + x2^2')
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)
plt.show()
